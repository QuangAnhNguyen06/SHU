# %%
import random
import lr_scheduler
import matplotlib.pyplot as plt
#from func import *
import func
import tensorflow as tf
import numpy as np
from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
from PIL import Image
import cv2
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.initializers import GlorotUniform
from PIL import Image, ImageEnhance

folder_path = "F:/code/barlow/UR5"
file_pairs = func.load_file_pairs(folder_path)

images = []
npy_file = []
for jpg_path, npy_path in file_pairs:
    images.append(func.read_jpg_files(jpg_path))
    npy_file.append(func.read_and_parse_npy_file(npy_path))


AUTO = tf.data.AUTOTUNE
CROP_TO = 32
SEED = 42
PROJECT_DIM = 2048
BATCH_SIZE = 32
EPOCHS = 10
STEPS_PER_EPOCH = 597 // BATCH_SIZE
TOTAL_STEPS = STEPS_PER_EPOCH * EPOCHS
WARMUP_EPOCHS = int(EPOCHS * 0.1)
WARMUP_STEPS = int(WARMUP_EPOCHS * STEPS_PER_EPOCH)

# %% [markdown]
# ### Traning

# %%
def compute_loss_cosine(z_a, z_b):
    # Normalize embeddings to unit vectors
    z_a_norm = tf.nn.l2_normalize(z_a, axis=1)
    z_b_norm = tf.nn.l2_normalize(z_b, axis=1)

    # Cosine similarity: mean of the negative cosine similarity
    cosine_similarity = tf.reduce_sum(z_a_norm * z_b_norm, axis=1)
    loss = 1 - tf.reduce_mean(cosine_similarity)  # Minimize (1 - similarity)
    return loss



def network_1():
    # Input layer for grayscale images
    inputs = layers.Input(shape=(128, 128, 1), name="image_input")
    
    # Convert grayscale to 3 channels (required by ResNet50)
    #x = layers.Conv2D(3, (3, 3), padding="same", activation="relu")(inputs)

    # cách khác thành nhân 3 grayscale
    x = layers.Lambda(lambda img: tf.image.grayscale_to_rgb(img))(inputs)
    
    # Use ResNet50 with pre-trained weights
    base_model = ResNet50(include_top=False, weights="imagenet", input_tensor=x)
    
    # Extract features
    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)
    
    # Add Dense layer with 30 units
    outputs = layers.Dense(30, activation="relu", name="latent_space")(x)
    
    return tf.keras.Model(inputs, outputs, name="ResNetImageNetwork")


# for layer in base_model.layers:
#     layer.trainable = False


def network_2():
    inputs = layers.Input(shape=(8,), name="npy_input")
    outputs = tf.keras.layers.Dense(10, activation="relu")(inputs)  # Joint embedding
    return tf.keras.Model(inputs, outputs, name="JointStateNetwork")


def combined_model():
    image_input = layers.Input(shape=(128, 128, 1), name="image_input")
    npy_input = layers.Input(shape=(8,), name="npy_input")
    
    image_output = network_1()(image_input)
    npy_output = network_2()(npy_input)
    
    combined = layers.Concatenate()([image_output, npy_output])
    latent_space = layers.Dense(20, activation="relu", name="latent_space")(combined)
    
    return tf.keras.Model(inputs=[image_input, npy_input], outputs=latent_space, name="CombinedModel")

@tf.function
def train_step(image1, image2, npy1, npy2, network1, network2, optimizer, lambda1, lambda2):
    with tf.GradientTape() as tape:
        # Forward pass for images
        z_img1 = network1(image1, training=True)
        z_img2 = network1(image2, training=True)
        loss1 = compute_loss_cosine(z_img1, z_img2)

        # Forward pass for joints
        z_npy1 = network2(npy1, training=True)
        z_npy2 = network2(npy2, training=True)
        loss2 = compute_loss_cosine(z_npy1, z_npy2)

        # Total loss
        total_loss = loss1 * lambda1 + loss2 * lambda2
    
    gradients = tape.gradient(total_loss, network1.trainable_variables + network2.trainable_variables)
    optimizer.apply_gradients(zip(gradients, network1.trainable_variables + network2.trainable_variables))
    
    return {"loss_total": total_loss, "loss1": loss1, "loss2": loss2}

# %%
def augment_image(image, crop_ratio=0.15):
    h, w = image.shape
    # Calculate crop dimensions
    crop_h = int(h * crop_ratio)
    crop_w = int(w * crop_ratio)

    # cropping
    cropped_image = image[crop_h:h-crop_h, crop_w:w-crop_w]

    # Resize back to original
    resized_image = cv2.resize(cropped_image, (w, h), interpolation=cv2.INTER_LINEAR)

    return resized_image

# No2. Augmentation Functions
def adjust_brightness(image, factor=1.2):
    """
    scale pixel values
    """
    adjusted = np.clip(image * factor, 0, 255).astype(np.uint8)
    return adjusted

def add_noise_vector(vector,alpha= 0.01):
    noise = np.random.normal(0, alpha, size=len(vector)) # alpha standard deviation
    augmented_vector = [v + n for v, n in zip(vector, noise)]
    #augmented_vector = [i.astype(float) for i in augmented_vector]
    return augmented_vector

def noise_aug_1(array, alpha=1.05):
    return np.array(array) * alpha

def noise_aug_2(array):
    scaler = StandardScaler()
    aug_arr = scaler.fit_transform(array)
    return aug_arr

# %%
# create train loss data
scaler = StandardScaler()

# image
image1 = [augment_image(img) for img in images]
image2 = [adjust_brightness(img, factor=1.2) for img in images]

# noise
npy_file_1 = [noise_aug_1(i,alpha= 1.05) for i in npy_file]
npy_file_2 = [noise_aug_1(i,alpha= 0.95) for i in npy_file]
npy_file_2 = noise_aug_2(npy_file)
# Normalize
image1 = [(i.astype("float32") / 255.0) for i in image1]
image2 = [(i.astype("float32") / 255.0) for i in image2]
# npy_file_1 = scaler.fit_transform(npy_file_1)
# npy_file_2 = scaler.fit_transform(npy_file_2)

img_ds_1 = tf.data.Dataset.from_tensor_slices(image1).batch(BATCH_SIZE)
img_ds_2 = tf.data.Dataset.from_tensor_slices(image2).batch(BATCH_SIZE)
npy_ds_1 = tf.data.Dataset.from_tensor_slices(npy_file_1).batch(BATCH_SIZE)
npy_ds_2 = tf.data.Dataset.from_tensor_slices(npy_file_2).batch(BATCH_SIZE)


# Combine image và vector thành input pairs
BL_ds = tf.data.Dataset.zip((img_ds_1, img_ds_2, npy_ds_1, npy_ds_2)).prefetch(tf.data.AUTOTUNE)
BL_ds_test = BL_ds

# %%
lr_decayed_fn = lr_scheduler.WarmUpCosine(
    learning_rate_base=1e-4,
    total_steps=EPOCHS * STEPS_PER_EPOCH,
    warmup_learning_rate=0.0,
    warmup_steps=WARMUP_STEPS
)

#lr_decayed_fn = 5e-4     # 0.005 = 5e-3

model = combined_model()
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_decayed_fn, momentum=0.9)
lambd = 5e-3 
EPOCHS = 20
lambda1 = 1/10
lambda2 = 1
network1 = network_1()
network2 = network_2()

for epoch in range(EPOCHS):
    for image1_batch, image2_batch, npy1_batch, npy2_batch in BL_ds_test:
        losses = train_step(image1_batch, image2_batch, npy1_batch, npy2_batch, network1, network2, optimizer, lambda1, lambda2)
    
    print(f"Epoch {epoch+1}, Total Loss: {losses['loss_total']:.4f}, Loss1: {losses['loss1']:.4f}, Loss2: {losses['loss2']:.4f}")
# Out:
# WARNING:tensorflow:From f:\code\barlow\env\lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 1, Total Loss: 0.6936, Loss1: 0.2738, Loss2: 0.6662
# Epoch 2, Total Loss: 0.6879, Loss1: 0.3035, Loss2: 0.6575
# Epoch 3, Total Loss: 0.6647, Loss1: 0.1694, Loss2: 0.6478
# Epoch 4, Total Loss: 0.6511, Loss1: 0.1204, Loss2: 0.6391
# Epoch 5, Total Loss: 0.6455, Loss1: 0.1349, Loss2: 0.6320
# Epoch 6, Total Loss: 0.6361, Loss1: 0.0926, Loss2: 0.6268
# Epoch 7, Total Loss: 0.6291, Loss1: 0.0572, Loss2: 0.6234
# Epoch 8, Total Loss: 0.6267, Loss1: 0.0521, Loss2: 0.6215
# Epoch 9, Total Loss: 0.6257, Loss1: 0.0504, Loss2: 0.6207
# Epoch 10, Total Loss: 0.6255, Loss1: 0.0499, Loss2: 0.6205
# Epoch 11, Total Loss: 0.6255, Loss1: 0.0499, Loss2: 0.6205
# Epoch 12, Total Loss: 0.6255, Loss1: 0.0499, Loss2: 0.6205
# Epoch 13, Total Loss: 0.6255, Loss1: 0.0499, Loss2: 0.6205
# Epoch 14, Total Loss: 0.6255, Loss1: 0.0499, Loss2: 0.6205
# Epoch 15, Total Loss: 0.6255, Loss1: 0.0499, Loss2: 0.6205
# Epoch 16, Total Loss: 0.6255, Loss1: 0.0499, Loss2: 0.6205
# Epoch 17, Total Loss: 0.6255, Loss1: 0.0499, Loss2: 0.6205
# Epoch 18, Total Loss: 0.6255, Loss1: 0.0499, Loss2: 0.6205
# Epoch 19, Total Loss: 0.6255, Loss1: 0.0499, Loss2: 0.6205
# Epoch 20, Total Loss: 0.6255, Loss1: 0.0499, Loss2: 0.6205

# %%
model.save_weights('combine_cosine_sim.weights.h5')

# %%
def create_decoder():
    latent_input = layers.Input(shape=(20,), name="latent_input")
    
    # Expand latent space to ... features
    expanded_features = layers.Dense(110, activation="relu")(latent_input)
    
    # Slice features for image and joint decoders
    image_features = layers.Lambda(lambda x: x[:, :100], name="image_features")(expanded_features)
    joint_features = layers.Lambda(lambda x: x[:, 100:], name="joint_features")(expanded_features)

    # Decode to image (Symmetric to network_1)
    latent_image = layers.Dense(100, name="latent_image")(image_features)
    
    # Tăng chiều từ embedding (30) lên kích thước phù hợp để reshape
    x_img = layers.Dense(8 * 8 * 64, activation="relu")(latent_image)  # Kích thước trung gian: 8x8x64
    x_img = layers.Reshape((8, 8, 64))(x_img)  # Reshape thành 8x8x64
    # Lần lượt dùng Conv2DTranspose và UpSampling2D để tăng dần kích thước
    x_img = layers.Conv2DTranspose(64, (3, 3), activation="relu", padding="same")(x_img)
    x_img = layers.UpSampling2D((2, 2))(x_img)  # (16, 16, 64)
    x_img = layers.Conv2DTranspose(128, (3, 3), activation="relu", padding="same")(x_img)
    x_img = layers.UpSampling2D((2, 2))(x_img)  # (32, 32, 128)
    x_img = layers.Conv2DTranspose(128, (3, 3), activation="relu", padding="same")(x_img)
    x_img = layers.UpSampling2D((2, 2))(x_img)  # (64, 64, 128)
    x_img = layers.Conv2DTranspose(64, (3, 3), activation="relu", padding="same")(x_img)
    x_img = layers.UpSampling2D((2, 2))(x_img)  # (128, 128, 64)
    # Tầng cuối cùng đưa về kích thước (128, 128, 1)
    image_output = layers.Conv2DTranspose(1, (3, 3), activation="sigmoid", padding="same", name="reconstructed_image")(x_img)
    

    # Decode to joints (Symmetric to network_2)
    x_npy = layers.Dense(10, activation="relu")(joint_features)
    joint_output = layers.Dense(8, activation="linear", name="reconstructed_joint")(x_npy)
    
    return tf.keras.Model(inputs=latent_input, outputs=[image_output, joint_output], name="Decoder")






def downstream_task(pretrained_model_path="combine_cosine_sim.weights.h5", freeze_up_to=None):
    # Load the pretrained model
    pretrained_model = combined_model()
    pretrained_model.load_weights(pretrained_model_path)

    # Freeze các lớp trong pretrained model (nếu cần)
    if freeze_up_to is not None:
        for layer in pretrained_model.layers[:-freeze_up_to]:
            layer.trainable = False

    # Input layers giống như mô hình đã pretrained
    image_input = pretrained_model.input[0]  # Input for images
    npy_input = pretrained_model.input[1]  # Input for joint state

    # Sử dụng output của pretrained model
    latent_space = pretrained_model.output

    # Thêm decoder
    decoder = create_decoder()
    image_output, joint_output = decoder(latent_space)

    # Tạo model mới
    downstream_model = tf.keras.Model(
        inputs=[image_input, npy_input],
        outputs=[image_output, joint_output],
        name="DownstreamModelWithDecoder"
    )
    return downstream_model

# %%
scaler = StandardScaler()

# Normalizing images
i1 = [(i.astype("float32") / 255.0).reshape(128, 128, 1) for i in images[:500]]
i2 = [(i.astype("float32") / 255.0).reshape(128, 128, 1) for i in images[500:]]

# Normalize joints
n1 = scaler.fit_transform(npy_file[:500])  # Joint data for training
n2 = scaler.fit_transform(npy_file[500:])     # Joint data for validation

# Create datasets
train_inputs = tf.data.Dataset.from_tensor_slices((i1, n1))
val_inputs = tf.data.Dataset.from_tensor_slices((i2, n2))

train_outputs = tf.data.Dataset.from_tensor_slices((i1, n1))
val_outputs = tf.data.Dataset.from_tensor_slices((i2, n2))

# Combine inputs and outputs into final datasets
train_ds = tf.data.Dataset.zip((train_inputs, train_outputs)).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
val_ds = tf.data.Dataset.zip((val_inputs, val_outputs)).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
# Tạo model với decoder
decoder_model = downstream_task(
    pretrained_model_path="combine_cosine_sim.weights.h5", 
    freeze_up_to = 15  # Freeze các lớp đầu tiên, fine-tune n lớp cuối
)

# Compile the model
# decoder_model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
#     loss={
#         "reconstructed_image": tf.keras.losses.MeanSquaredError(),  # Loss cho image reconstruction
#         "reconstructed_joint": tf.keras.losses.MeanSquaredError(),  # Loss cho joint reconstruction
#     },
#     loss_weights={
#         "reconstructed_image": 3.0,  # Trọng số cho loss image
#         "reconstructed_joint": 1.0,  # Trọng số cho loss joint
#     },
#     metrics={
#         "reconstructed_image": [tf.keras.metrics.MeanSquaredError(name="mse_image")],
#         "reconstructed_joint": [tf.keras.metrics.MeanSquaredError(name="mse_joint")],
#     }
# )

decoder_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=["mse", "mse"],  # Loss cho ảnh và joints
    loss_weights=[3.0, 1.0],  # image:joints ratio
    metrics=["mae",'mae']
)

# %%
#Train
history = decoder_model.fit(
    train_ds,  # Dataset both (image_input, npy_input) and (image_output, joint_output)
    validation_data=val_ds,
    epochs=100,
    batch_size=32,
    verbose=1
)
# decoder_model.load_weights("reconstruct_cosine_sim.weights.h5")
# Out:
# Epoch 1/100
# f:\code\barlow\env\lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['image_input', 'npy_input']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - Decoder_loss: 0.8969 - Decoder_mae: 0.1207 - Decoder_mae_1: 0.6236 - loss: 0.9619 - val_Decoder_loss: 1.5408 - val_Decoder_mae: 0.2629 - val_Decoder_mae_1: 0.8920 - val_loss: 1.7251
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.7388 - Decoder_mae: 0.0531 - Decoder_mae_1: 0.5768 - loss: 0.7537 - val_Decoder_loss: 277.2262 - val_Decoder_mae: 0.2880 - val_Decoder_mae_1: 13.6576 - val_loss: 277.7423
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.6556 - Decoder_mae: 0.0459 - Decoder_mae_1: 0.5446 - loss: 0.6685 - val_Decoder_loss: 1.8507 - val_Decoder_mae: 0.1362 - val_Decoder_mae_1: 1.0250 - val_loss: 1.8751
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.5720 - Decoder_mae: 0.0366 - Decoder_mae_1: 0.5173 - loss: 0.5821 - val_Decoder_loss: 6.8921 - val_Decoder_mae: 0.0522 - val_Decoder_mae_1: 2.0184 - val_loss: 6.6945
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.5140 - Decoder_mae: 0.0342 - Decoder_mae_1: 0.4864 - loss: 0.5230 - val_Decoder_loss: 22.0069 - val_Decoder_mae: 0.0704 - val_Decoder_mae_1: 3.7958 - val_loss: 21.7209
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - Decoder_loss: 0.4725 - Decoder_mae: 0.0345 - Decoder_mae_1: 0.4617 - loss: 0.4815 - val_Decoder_loss: 12.2232 - val_Decoder_mae: 0.0451 - val_Decoder_mae_1: 2.8118 - val_loss: 12.0060
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - Decoder_loss: 0.4127 - Decoder_mae: 0.0314 - Decoder_mae_1: 0.4442 - loss: 0.4208 - val_Decoder_loss: 4.5124 - val_Decoder_mae: 0.0765 - val_Decoder_mae_1: 1.6414 - val_loss: 4.3830
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.3799 - Decoder_mae: 0.0280 - Decoder_mae_1: 0.4186 - loss: 0.3875 - val_Decoder_loss: 1.9439 - val_Decoder_mae: 0.0882 - val_Decoder_mae_1: 1.0277 - val_loss: 1.8683
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.3255 - Decoder_mae: 0.0266 - Decoder_mae_1: 0.4004 - loss: 0.3322 - val_Decoder_loss: 1.7003 - val_Decoder_mae: 0.0880 - val_Decoder_mae_1: 0.9597 - val_loss: 1.6327
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.2923 - Decoder_mae: 0.0243 - Decoder_mae_1: 0.3824 - loss: 0.2985 - val_Decoder_loss: 1.6874 - val_Decoder_mae: 0.0781 - val_Decoder_mae_1: 0.9596 - val_loss: 1.6166
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.2628 - Decoder_mae: 0.0234 - Decoder_mae_1: 0.3632 - loss: 0.2687 - val_Decoder_loss: 2.0658 - val_Decoder_mae: 0.0715 - val_Decoder_mae_1: 1.0809 - val_loss: 1.9816
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.2387 - Decoder_mae: 0.0221 - Decoder_mae_1: 0.3434 - loss: 0.2442 - val_Decoder_loss: 1.7217 - val_Decoder_mae: 0.0720 - val_Decoder_mae_1: 0.9791 - val_loss: 1.6480
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.2189 - Decoder_mae: 0.0204 - Decoder_mae_1: 0.3282 - loss: 0.2240 - val_Decoder_loss: 1.7599 - val_Decoder_mae: 0.0632 - val_Decoder_mae_1: 0.9968 - val_loss: 1.6848
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.2028 - Decoder_mae: 0.0193 - Decoder_mae_1: 0.3160 - loss: 0.2077 - val_Decoder_loss: 2.1138 - val_Decoder_mae: 0.0579 - val_Decoder_mae_1: 1.1117 - val_loss: 2.0275
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1902 - Decoder_mae: 0.0191 - Decoder_mae_1: 0.3052 - loss: 0.1949 - val_Decoder_loss: 2.0729 - val_Decoder_mae: 0.0562 - val_Decoder_mae_1: 1.1053 - val_loss: 1.9900
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1756 - Decoder_mae: 0.0191 - Decoder_mae_1: 0.2919 - loss: 0.1804 - val_Decoder_loss: 2.0588 - val_Decoder_mae: 0.0543 - val_Decoder_mae_1: 1.1037 - val_loss: 1.9766
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1763 - Decoder_mae: 0.0182 - Decoder_mae_1: 0.2971 - loss: 0.1809 - val_Decoder_loss: 2.0218 - val_Decoder_mae: 0.0503 - val_Decoder_mae_1: 1.0934 - val_loss: 1.9381
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1848 - Decoder_mae: 0.0190 - Decoder_mae_1: 0.3137 - loss: 0.1897 - val_Decoder_loss: 2.0200 - val_Decoder_mae: 0.0508 - val_Decoder_mae_1: 1.0961 - val_loss: 1.9403
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1597 - Decoder_mae: 0.0178 - Decoder_mae_1: 0.2841 - loss: 0.1640 - val_Decoder_loss: 2.2106 - val_Decoder_mae: 0.0423 - val_Decoder_mae_1: 1.1578 - val_loss: 2.1277
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1603 - Decoder_mae: 0.0165 - Decoder_mae_1: 0.2840 - loss: 0.1644 - val_Decoder_loss: 3.3111 - val_Decoder_mae: 0.0430 - val_Decoder_mae_1: 1.4442 - val_loss: 3.2060
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1647 - Decoder_mae: 0.0170 - Decoder_mae_1: 0.2907 - loss: 0.1693 - val_Decoder_loss: 4.0420 - val_Decoder_mae: 0.0402 - val_Decoder_mae_1: 1.5911 - val_loss: 3.9146
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1539 - Decoder_mae: 0.0160 - Decoder_mae_1: 0.2786 - loss: 0.1580 - val_Decoder_loss: 3.0287 - val_Decoder_mae: 0.0435 - val_Decoder_mae_1: 1.3772 - val_loss: 2.9174
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1470 - Decoder_mae: 0.0165 - Decoder_mae_1: 0.2698 - loss: 0.1513 - val_Decoder_loss: 1.9736 - val_Decoder_mae: 0.0417 - val_Decoder_mae_1: 1.0877 - val_loss: 1.8884
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1415 - Decoder_mae: 0.0171 - Decoder_mae_1: 0.2670 - loss: 0.1457 - val_Decoder_loss: 2.4815 - val_Decoder_mae: 0.0421 - val_Decoder_mae_1: 1.2442 - val_loss: 2.3840
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - Decoder_loss: 0.1216 - Decoder_mae: 0.0166 - Decoder_mae_1: 0.2464 - loss: 0.1257 - val_Decoder_loss: 3.0391 - val_Decoder_mae: 0.0401 - val_Decoder_mae_1: 1.3876 - val_loss: 2.9305
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1188 - Decoder_mae: 0.0162 - Decoder_mae_1: 0.2426 - loss: 0.1227 - val_Decoder_loss: 2.9522 - val_Decoder_mae: 0.0399 - val_Decoder_mae_1: 1.3553 - val_loss: 2.8399
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1169 - Decoder_mae: 0.0153 - Decoder_mae_1: 0.2418 - loss: 0.1206 - val_Decoder_loss: 2.7090 - val_Decoder_mae: 0.0427 - val_Decoder_mae_1: 1.2896 - val_loss: 2.5981
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1145 - Decoder_mae: 0.0153 - Decoder_mae_1: 0.2357 - loss: 0.1183 - val_Decoder_loss: 3.2387 - val_Decoder_mae: 0.0402 - val_Decoder_mae_1: 1.4309 - val_loss: 3.1253
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1071 - Decoder_mae: 0.0153 - Decoder_mae_1: 0.2321 - loss: 0.1106 - val_Decoder_loss: 2.9763 - val_Decoder_mae: 0.0391 - val_Decoder_mae_1: 1.3771 - val_loss: 2.8687
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1009 - Decoder_mae: 0.0146 - Decoder_mae_1: 0.2235 - loss: 0.1044 - val_Decoder_loss: 2.7096 - val_Decoder_mae: 0.0404 - val_Decoder_mae_1: 1.3128 - val_loss: 2.6122
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0995 - Decoder_mae: 0.0150 - Decoder_mae_1: 0.2202 - loss: 0.1031 - val_Decoder_loss: 1.7673 - val_Decoder_mae: 0.0394 - val_Decoder_mae_1: 1.0332 - val_loss: 1.6948
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0955 - Decoder_mae: 0.0153 - Decoder_mae_1: 0.2125 - loss: 0.0991 - val_Decoder_loss: 2.7751 - val_Decoder_mae: 0.0391 - val_Decoder_mae_1: 1.3294 - val_loss: 2.6764
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0904 - Decoder_mae: 0.0144 - Decoder_mae_1: 0.2085 - loss: 0.0937 - val_Decoder_loss: 3.8859 - val_Decoder_mae: 0.0387 - val_Decoder_mae_1: 1.5790 - val_loss: 3.7617
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.2068 - Decoder_mae: 0.0153 - Decoder_mae_1: 0.2560 - loss: 0.2108 - val_Decoder_loss: 243.6893 - val_Decoder_mae: 0.2411 - val_Decoder_mae_1: 11.1534 - val_loss: 242.4627
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.2955 - Decoder_mae: 0.0238 - Decoder_mae_1: 0.3369 - loss: 0.3024 - val_Decoder_loss: 43424.4727 - val_Decoder_mae: 0.2909 - val_Decoder_mae_1: 150.6622 - val_loss: 43414.0234
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1527 - Decoder_mae: 0.0207 - Decoder_mae_1: 0.2598 - loss: 0.1583 - val_Decoder_loss: 2524.7488 - val_Decoder_mae: 0.2794 - val_Decoder_mae_1: 37.5215 - val_loss: 2521.2756
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1640 - Decoder_mae: 0.0180 - Decoder_mae_1: 0.2658 - loss: 0.1691 - val_Decoder_loss: 11016.3799 - val_Decoder_mae: 0.2915 - val_Decoder_mae_1: 77.4625 - val_loss: 11046.8789
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1248 - Decoder_mae: 0.0182 - Decoder_mae_1: 0.2422 - loss: 0.1300 - val_Decoder_loss: 11281.3076 - val_Decoder_mae: 0.2918 - val_Decoder_mae_1: 86.9069 - val_loss: 11293.0225
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1108 - Decoder_mae: 0.0166 - Decoder_mae_1: 0.2274 - loss: 0.1152 - val_Decoder_loss: 780.3727 - val_Decoder_mae: 0.2512 - val_Decoder_mae_1: 23.2538 - val_loss: 782.0978
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.1082 - Decoder_mae: 0.0155 - Decoder_mae_1: 0.2212 - loss: 0.1125 - val_Decoder_loss: 4.2550 - val_Decoder_mae: 0.0463 - val_Decoder_mae_1: 1.5756 - val_loss: 4.2249
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0873 - Decoder_mae: 0.0145 - Decoder_mae_1: 0.1998 - loss: 0.0911 - val_Decoder_loss: 22.7317 - val_Decoder_mae: 0.0388 - val_Decoder_mae_1: 3.6847 - val_loss: 22.2158
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0755 - Decoder_mae: 0.0129 - Decoder_mae_1: 0.1868 - loss: 0.0788 - val_Decoder_loss: 3.3268 - val_Decoder_mae: 0.0375 - val_Decoder_mae_1: 1.4390 - val_loss: 3.2044
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0695 - Decoder_mae: 0.0123 - Decoder_mae_1: 0.1795 - loss: 0.0726 - val_Decoder_loss: 1.5332 - val_Decoder_mae: 0.0375 - val_Decoder_mae_1: 0.9946 - val_loss: 1.4763
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0653 - Decoder_mae: 0.0120 - Decoder_mae_1: 0.1729 - loss: 0.0683 - val_Decoder_loss: 1.6166 - val_Decoder_mae: 0.0361 - val_Decoder_mae_1: 1.0528 - val_loss: 1.5641
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0615 - Decoder_mae: 0.0117 - Decoder_mae_1: 0.1684 - loss: 0.0644 - val_Decoder_loss: 1.1623 - val_Decoder_mae: 0.0372 - val_Decoder_mae_1: 0.8831 - val_loss: 1.1231
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0605 - Decoder_mae: 0.0116 - Decoder_mae_1: 0.1662 - loss: 0.0634 - val_Decoder_loss: 1.0552 - val_Decoder_mae: 0.0366 - val_Decoder_mae_1: 0.8393 - val_loss: 1.0273
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0581 - Decoder_mae: 0.0113 - Decoder_mae_1: 0.1637 - loss: 0.0608 - val_Decoder_loss: 1.0030 - val_Decoder_mae: 0.0360 - val_Decoder_mae_1: 0.8063 - val_loss: 0.9770
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0564 - Decoder_mae: 0.0114 - Decoder_mae_1: 0.1626 - loss: 0.0591 - val_Decoder_loss: 1.0008 - val_Decoder_mae: 0.0358 - val_Decoder_mae_1: 0.8082 - val_loss: 0.9781
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0548 - Decoder_mae: 0.0113 - Decoder_mae_1: 0.1608 - loss: 0.0575 - val_Decoder_loss: 0.9938 - val_Decoder_mae: 0.0360 - val_Decoder_mae_1: 0.8054 - val_loss: 0.9745
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0527 - Decoder_mae: 0.0112 - Decoder_mae_1: 0.1569 - loss: 0.0554 - val_Decoder_loss: 1.0030 - val_Decoder_mae: 0.0343 - val_Decoder_mae_1: 0.8153 - val_loss: 0.9877
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0499 - Decoder_mae: 0.0112 - Decoder_mae_1: 0.1518 - loss: 0.0527 - val_Decoder_loss: 1.0060 - val_Decoder_mae: 0.0339 - val_Decoder_mae_1: 0.8193 - val_loss: 0.9940
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0471 - Decoder_mae: 0.0116 - Decoder_mae_1: 0.1456 - loss: 0.0498 - val_Decoder_loss: 1.0079 - val_Decoder_mae: 0.0332 - val_Decoder_mae_1: 0.8214 - val_loss: 0.9981
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0450 - Decoder_mae: 0.0120 - Decoder_mae_1: 0.1414 - loss: 0.0476 - val_Decoder_loss: 1.0101 - val_Decoder_mae: 0.0334 - val_Decoder_mae_1: 0.8235 - val_loss: 1.0027
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0436 - Decoder_mae: 0.0114 - Decoder_mae_1: 0.1377 - loss: 0.0460 - val_Decoder_loss: 1.0324 - val_Decoder_mae: 0.0335 - val_Decoder_mae_1: 0.8403 - val_loss: 1.0283
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0418 - Decoder_mae: 0.0109 - Decoder_mae_1: 0.1346 - loss: 0.0442 - val_Decoder_loss: 1.0317 - val_Decoder_mae: 0.0336 - val_Decoder_mae_1: 0.8398 - val_loss: 1.0284
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0409 - Decoder_mae: 0.0100 - Decoder_mae_1: 0.1322 - loss: 0.0430 - val_Decoder_loss: 1.0504 - val_Decoder_mae: 0.0331 - val_Decoder_mae_1: 0.8529 - val_loss: 1.0488
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0392 - Decoder_mae: 0.0099 - Decoder_mae_1: 0.1298 - loss: 0.0414 - val_Decoder_loss: 1.0644 - val_Decoder_mae: 0.0339 - val_Decoder_mae_1: 0.8604 - val_loss: 1.0630
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0388 - Decoder_mae: 0.0097 - Decoder_mae_1: 0.1284 - loss: 0.0409 - val_Decoder_loss: 1.0958 - val_Decoder_mae: 0.0332 - val_Decoder_mae_1: 0.8789 - val_loss: 1.0959
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0383 - Decoder_mae: 0.0097 - Decoder_mae_1: 0.1284 - loss: 0.0404 - val_Decoder_loss: 1.1431 - val_Decoder_mae: 0.0335 - val_Decoder_mae_1: 0.9014 - val_loss: 1.1427
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0380 - Decoder_mae: 0.0096 - Decoder_mae_1: 0.1283 - loss: 0.0402 - val_Decoder_loss: 1.1653 - val_Decoder_mae: 0.0328 - val_Decoder_mae_1: 0.9111 - val_loss: 1.1650
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0387 - Decoder_mae: 0.0097 - Decoder_mae_1: 0.1312 - loss: 0.0408 - val_Decoder_loss: 1.2586 - val_Decoder_mae: 0.0329 - val_Decoder_mae_1: 0.9550 - val_loss: 1.2612
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0411 - Decoder_mae: 0.0099 - Decoder_mae_1: 0.1391 - loss: 0.0435 - val_Decoder_loss: 1.3223 - val_Decoder_mae: 0.0345 - val_Decoder_mae_1: 0.9796 - val_loss: 1.3251
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0421 - Decoder_mae: 0.0106 - Decoder_mae_1: 0.1416 - loss: 0.0448 - val_Decoder_loss: 1.3678 - val_Decoder_mae: 0.0353 - val_Decoder_mae_1: 0.9981 - val_loss: 1.3715
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0398 - Decoder_mae: 0.0108 - Decoder_mae_1: 0.1361 - loss: 0.0425 - val_Decoder_loss: 1.4231 - val_Decoder_mae: 0.0346 - val_Decoder_mae_1: 1.0172 - val_loss: 1.4277
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0382 - Decoder_mae: 0.0126 - Decoder_mae_1: 0.1328 - loss: 0.0413 - val_Decoder_loss: 1.5301 - val_Decoder_mae: 0.0372 - val_Decoder_mae_1: 1.0485 - val_loss: 1.5361
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0377 - Decoder_mae: 0.0109 - Decoder_mae_1: 0.1317 - loss: 0.0402 - val_Decoder_loss: 1.5570 - val_Decoder_mae: 0.0371 - val_Decoder_mae_1: 1.0568 - val_loss: 1.5625
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0349 - Decoder_mae: 0.0097 - Decoder_mae_1: 0.1224 - loss: 0.0370 - val_Decoder_loss: 1.6487 - val_Decoder_mae: 0.0371 - val_Decoder_mae_1: 1.0850 - val_loss: 1.6557
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0358 - Decoder_mae: 0.0102 - Decoder_mae_1: 0.1242 - loss: 0.0382 - val_Decoder_loss: 1.5867 - val_Decoder_mae: 0.0354 - val_Decoder_mae_1: 1.0627 - val_loss: 1.5906
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0361 - Decoder_mae: 0.0097 - Decoder_mae_1: 0.1257 - loss: 0.0383 - val_Decoder_loss: 1.5722 - val_Decoder_mae: 0.0370 - val_Decoder_mae_1: 1.0644 - val_loss: 1.5855
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0350 - Decoder_mae: 0.0090 - Decoder_mae_1: 0.1220 - loss: 0.0369 - val_Decoder_loss: 1.7100 - val_Decoder_mae: 0.0366 - val_Decoder_mae_1: 1.1133 - val_loss: 1.7417
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0355 - Decoder_mae: 0.0089 - Decoder_mae_1: 0.1229 - loss: 0.0373 - val_Decoder_loss: 1.5975 - val_Decoder_mae: 0.0338 - val_Decoder_mae_1: 1.0811 - val_loss: 1.6378
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0372 - Decoder_mae: 0.0093 - Decoder_mae_1: 0.1285 - loss: 0.0392 - val_Decoder_loss: 1.9505 - val_Decoder_mae: 0.0318 - val_Decoder_mae_1: 1.1878 - val_loss: 1.9979
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0373 - Decoder_mae: 0.0100 - Decoder_mae_1: 0.1307 - loss: 0.0398 - val_Decoder_loss: 1.6864 - val_Decoder_mae: 0.0304 - val_Decoder_mae_1: 1.1041 - val_loss: 1.7226
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - Decoder_loss: 0.0404 - Decoder_mae: 0.0108 - Decoder_mae_1: 0.1376 - loss: 0.0430 - val_Decoder_loss: 1.5192 - val_Decoder_mae: 0.0304 - val_Decoder_mae_1: 1.0340 - val_loss: 1.5540
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0492 - Decoder_mae: 0.0103 - Decoder_mae_1: 0.1575 - loss: 0.0517 - val_Decoder_loss: 0.9505 - val_Decoder_mae: 0.0255 - val_Decoder_mae_1: 0.8138 - val_loss: 0.9784
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0538 - Decoder_mae: 0.0117 - Decoder_mae_1: 0.1625 - loss: 0.0569 - val_Decoder_loss: 0.7646 - val_Decoder_mae: 0.0209 - val_Decoder_mae_1: 0.7102 - val_loss: 0.7849
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0469 - Decoder_mae: 0.0114 - Decoder_mae_1: 0.1521 - loss: 0.0497 - val_Decoder_loss: 0.5847 - val_Decoder_mae: 0.0165 - val_Decoder_mae_1: 0.5839 - val_loss: 0.5908
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0324 - Decoder_mae: 0.0094 - Decoder_mae_1: 0.1177 - loss: 0.0345 - val_Decoder_loss: 0.4819 - val_Decoder_mae: 0.0151 - val_Decoder_mae_1: 0.5222 - val_loss: 0.4850
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0292 - Decoder_mae: 0.0089 - Decoder_mae_1: 0.1068 - loss: 0.0311 - val_Decoder_loss: 0.4289 - val_Decoder_mae: 0.0139 - val_Decoder_mae_1: 0.4825 - val_loss: 0.4280
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0279 - Decoder_mae: 0.0084 - Decoder_mae_1: 0.1045 - loss: 0.0296 - val_Decoder_loss: 0.4020 - val_Decoder_mae: 0.0126 - val_Decoder_mae_1: 0.4670 - val_loss: 0.3991
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0267 - Decoder_mae: 0.0081 - Decoder_mae_1: 0.1005 - loss: 0.0284 - val_Decoder_loss: 0.3633 - val_Decoder_mae: 0.0115 - val_Decoder_mae_1: 0.4418 - val_loss: 0.3580
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0262 - Decoder_mae: 0.0080 - Decoder_mae_1: 0.0994 - loss: 0.0278 - val_Decoder_loss: 0.3198 - val_Decoder_mae: 0.0102 - val_Decoder_mae_1: 0.4066 - val_loss: 0.3113
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0254 - Decoder_mae: 0.0078 - Decoder_mae_1: 0.0974 - loss: 0.0269 - val_Decoder_loss: 0.3057 - val_Decoder_mae: 0.0102 - val_Decoder_mae_1: 0.3965 - val_loss: 0.2965
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0249 - Decoder_mae: 0.0077 - Decoder_mae_1: 0.0964 - loss: 0.0263 - val_Decoder_loss: 0.2947 - val_Decoder_mae: 0.0096 - val_Decoder_mae_1: 0.3817 - val_loss: 0.2842
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0246 - Decoder_mae: 0.0078 - Decoder_mae_1: 0.0957 - loss: 0.0261 - val_Decoder_loss: 0.2866 - val_Decoder_mae: 0.0093 - val_Decoder_mae_1: 0.3757 - val_loss: 0.2766
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0242 - Decoder_mae: 0.0078 - Decoder_mae_1: 0.0949 - loss: 0.0256 - val_Decoder_loss: 0.2797 - val_Decoder_mae: 0.0088 - val_Decoder_mae_1: 0.3644 - val_loss: 0.2694
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0235 - Decoder_mae: 0.0077 - Decoder_mae_1: 0.0924 - loss: 0.0250 - val_Decoder_loss: 0.2669 - val_Decoder_mae: 0.0084 - val_Decoder_mae_1: 0.3505 - val_loss: 0.2568
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0237 - Decoder_mae: 0.0079 - Decoder_mae_1: 0.0931 - loss: 0.0253 - val_Decoder_loss: 0.2537 - val_Decoder_mae: 0.0085 - val_Decoder_mae_1: 0.3257 - val_loss: 0.2437
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0236 - Decoder_mae: 0.0083 - Decoder_mae_1: 0.0922 - loss: 0.0254 - val_Decoder_loss: 0.2447 - val_Decoder_mae: 0.0099 - val_Decoder_mae_1: 0.3157 - val_loss: 0.2351
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0237 - Decoder_mae: 0.0091 - Decoder_mae_1: 0.0942 - loss: 0.0257 - val_Decoder_loss: 0.2440 - val_Decoder_mae: 0.0103 - val_Decoder_mae_1: 0.3100 - val_loss: 0.2329
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0235 - Decoder_mae: 0.0093 - Decoder_mae_1: 0.0944 - loss: 0.0252 - val_Decoder_loss: 0.2447 - val_Decoder_mae: 0.0092 - val_Decoder_mae_1: 0.3156 - val_loss: 0.2336
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0231 - Decoder_mae: 0.0085 - Decoder_mae_1: 0.0931 - loss: 0.0246 - val_Decoder_loss: 0.2501 - val_Decoder_mae: 0.0081 - val_Decoder_mae_1: 0.3178 - val_loss: 0.2392
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0229 - Decoder_mae: 0.0083 - Decoder_mae_1: 0.0913 - loss: 0.0244 - val_Decoder_loss: 0.2484 - val_Decoder_mae: 0.0080 - val_Decoder_mae_1: 0.3235 - val_loss: 0.2382
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0233 - Decoder_mae: 0.0080 - Decoder_mae_1: 0.0923 - loss: 0.0248 - val_Decoder_loss: 0.2510 - val_Decoder_mae: 0.0080 - val_Decoder_mae_1: 0.3216 - val_loss: 0.2407
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0236 - Decoder_mae: 0.0080 - Decoder_mae_1: 0.0912 - loss: 0.0252 - val_Decoder_loss: 0.2429 - val_Decoder_mae: 0.0088 - val_Decoder_mae_1: 0.3190 - val_loss: 0.2322
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0227 - Decoder_mae: 0.0085 - Decoder_mae_1: 0.0913 - loss: 0.0245 - val_Decoder_loss: 0.2389 - val_Decoder_mae: 0.0094 - val_Decoder_mae_1: 0.3074 - val_loss: 0.2282
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0221 - Decoder_mae: 0.0089 - Decoder_mae_1: 0.0911 - loss: 0.0240 - val_Decoder_loss: 0.2340 - val_Decoder_mae: 0.0098 - val_Decoder_mae_1: 0.3016 - val_loss: 0.2240
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0215 - Decoder_mae: 0.0088 - Decoder_mae_1: 0.0900 - loss: 0.0235 - val_Decoder_loss: 0.2333 - val_Decoder_mae: 0.0090 - val_Decoder_mae_1: 0.2916 - val_loss: 0.2240
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0214 - Decoder_mae: 0.0087 - Decoder_mae_1: 0.0893 - loss: 0.0232 - val_Decoder_loss: 0.2308 - val_Decoder_mae: 0.0088 - val_Decoder_mae_1: 0.2943 - val_loss: 0.2211
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - Decoder_loss: 0.0214 - Decoder_mae: 0.0082 - Decoder_mae_1: 0.0897 - loss: 0.0230 - val_Decoder_loss: 0.2338 - val_Decoder_mae: 0.0080 - val_Decoder_mae_1: 0.2898 - val_loss: 0.2239

# %%
# Visualize reconstructed images
for data, labels in val_ds.take(1):
    img_input = data[0]
    joint_input = data[1]
    true_img = labels[0]
    true_joint = labels[1]

    # Predict reconstructions
    predicted_img, predicted_joint = decoder_model.predict({"image_input": img_input, "npy_input": joint_input})

# # Lấy một batch từ validation dataset
# for batch in val_ds.take(1):
#     (input_images, input_joints), (real_images, real_joints) = batch

# Convert tensor sang numpy array nếu cần
real_images = true_img.numpy()  # Ground truth (thực tế)
predicted_images = predicted_img  # Dự đoán (đã có sẵn dưới dạng numpy array)



def plot_real_vs_predicted(real_images, predicted_images, n=8):
    # # Lấy một batch từ validation dataset
    # for batch in val_ds.take(1):
    #     (input_images, input_joints), (real_images, real_joints) = batch

    # # Convert tensor sang numpy array nếu cần
    # real_images = real_images.numpy()
    # predicted_images = np.array(predicted_images)  # Convert predicted_images nếu cần
    
    # Đảm bảo n không vượt quá số lượng ảnh trong batch
    n = min(n, real_images.shape[0], predicted_images.shape[0])
    
    cols = min(4, n)  # Giới hạn số cột để giữ ảnh lớn hơn
    rows = (n + cols - 1) // cols  # Số hàng được tính tự động để vừa với n ảnh

    # Tạo một figure để hiển thị ảnh
    fig, axes = plt.subplots(2 * rows, cols, figsize=(10, 10))  # Gấp đôi số hàng để hiển thị cả ảnh thực tế và dự đoán
    fig.suptitle("Real vs Predicted Images (Grayscale)", fontsize=16)

    # Plot ảnh thực tế và dự đoán
    for i in range(n):
        # Plot ảnh thực tế
        ax_real = axes[2 * (i // cols), i % cols]  # Dòng chẵn: ảnh thực tế
        ax_real.imshow(real_images[i, :, :, 0], cmap='gray')
        ax_real.axis("off")
        ax_real.set_title(f"Real {i+1}")

        # Plot ảnh dự đoán
        ax_pred = axes[2 * (i // cols) + 1, i % cols]  # Dòng lẻ: ảnh dự đoán
        ax_pred.imshow(predicted_images[i, :, :, 0], cmap='gray')
        ax_pred.axis("off")
        ax_pred.set_title(f"Predicted {i+1}")

    plt.tight_layout()
    plt.subplots_adjust(top=0.92)  # Điều chỉnh tiêu đề không bị chèn lên các ảnh
    plt.show()

# Sử dụng hàm với n ảnh tùy chỉnh
plot_real_vs_predicted(real_images, predicted_images, n=8)
# Out:
# f:\code\barlow\env\lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['image_input', 'npy_input']. Received: the structure of inputs={'image_input': '*', 'npy_input': '*'}
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
decoder_model.save_weights("reconstruct_cosine_sim.weights.weights.h5")

# %%
decoder_model.summary()
# Out:
# Model: "DownstreamModelWithDecoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ image_input         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ npy_input           │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ResNetImageNetwork  │ (None, 30)        │ 23,649,182 │ image_input[0][0] │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ JointStateNetwork   │ (None, 10)        │         90 │ npy_input[0][0]   │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 40)        │          0 │ ResNetImageNetwo… │
# │ (Concatenate)       │                   │            │ JointStateNetwor… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ latent_space        │ (None, 20)        │        820 │ concatenate_1[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Decoder             │ [(None, 128, 128, │    759,041 │ latent_space[0][… │
# │ (Functional)        │ 1), (None, 8)]    │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 73,121,161 (278.94 MB)
#  Trainable params: 24,356,013 (92.91 MB)
#  Non-trainable params: 53,120 (207.50 KB)
#  Optimizer params: 48,712,028 (185.82 MB)
