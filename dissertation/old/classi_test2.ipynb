# %%
import os
import numpy as np
from PIL import Image
import tensorflow as tf
import random
import lr_scheduler
import func

folder_path = "F:/code/barlow/UR5"
file_pairs = func.load_file_pairs(folder_path)

AUTO = tf.data.AUTOTUNE
CROP_TO = 32
SEED = 200

PROJECT_DIM = 2048
BATCH_SIZE = 32
EPOCHS = 50

# %%
random_500_similar, random_500_dissimilar, remaining_similar, remaining_dissimilar = func.split_and_shuffle_pairs(file_pairs, folder_path)

def process_data(data_list):
    return [
        [func.read_jpg_files(jpg_path), func.read_and_parse_npy_file(npy_path)]
        for jpg_path, npy_path in data_list
    ]

xtrain1 = process_data(random_500_similar)
xtrain2 = process_data(random_500_dissimilar)
xtest1 = process_data(remaining_similar)
xtest2 = process_data(remaining_dissimilar)

# label 1 - similar, 0 - disimilar
ytrain1 = [1] * 500
ytrain2 = [0] * 500
ytest1 = [1] *79
ytest2 = [0] *79

y_train = ytrain1 + ytrain2
y_test = ytest1 + ytest2
x_train = xtrain1 + xtrain2
x_test = xtest1 + xtest2

# %%
# Train data
t1 = np.array([item[0] for item in x_train])  # Lấy phần ảnh
t2 = np.array([item[1] for item in x_train])  # Lấy phần npy vector
train_ds = tf.data.Dataset.from_tensor_slices(((t1, t2),y_train))
train_ds = train_ds.map(
    lambda inputs, y: (func.combine_data(*inputs), y),
    num_parallel_calls=tf.data.AUTOTUNE
)
train_ds = (
    train_ds
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)

# %%
# Test data
t3 = np.array([item[0] for item in x_test])  # Lấy phần ảnh
t4 = np.array([item[1] for item in x_test])  # Lấy phần npy vector
test_ds = tf.data.Dataset.from_tensor_slices(((t3, t4),y_test))
test_ds = test_ds.map(
    lambda inputs, y: (func.combine_data(*inputs), y),
    num_parallel_calls=tf.data.AUTOTUNE
)
test_ds = (
    test_ds
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)

# %%
def create_mlp_encoder(input_dim):
    inputs = tf.keras.Input(shape=(input_dim,))
    x = tf.keras.layers.Dense(512, activation="relu")(inputs)
    x = tf.keras.layers.Dense(256, activation="relu")(x)
    x = tf.keras.layers.Dense(128, activation=None)(x)  # Projection head
    return tf.keras.Model(inputs, x)

# Tạo encoder mới
mlp_encoder = create_mlp_encoder(input_dim=16392)
# Sử dụng encoder MLP cho Barlow Twins
barlow_twins = func.BarlowTwins(encoder=mlp_encoder)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.00005, momentum=0.9)
barlow_twins.compile(optimizer=optimizer)

barlow_twins.load_weights('bl.weights.h5')

# %%
# Extract backbone từ MLP encoder
backbone = tf.keras.Model(
    inputs=barlow_twins.encoder.input,
    outputs=barlow_twins.encoder.layers[-1].output  # output từ lớp Dense(128)
)
# Freeze backbone
backbone.trainable = False

# Thêm classifier
inputs = tf.keras.layers.Input(shape=(16392,))
x = backbone(inputs, training=False)

#outputs = tf.keras.layers.Dense(10, activation="relu")(x)
outputs = tf.keras.layers.Dense(2, activation="relu")(x)

test_model = tf.keras.Model(inputs, outputs, name="test_model")

# %%
# Shuffle train_ds vs test_ds 
seed = 123
train_ds = train_ds.shuffle(buffer_size=10, seed=seed, reshuffle_each_iteration=True)
test_ds = test_ds.shuffle(buffer_size=10, seed=seed, reshuffle_each_iteration=True)

# %%
# Compile model
test_model.compile(
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
    #optimizer = tf.keras.optimizers.SGD(learning_rate=0.00005, momentum=0.9)
)

history = test_model.fit(
    train_ds, validation_data=test_ds, epochs=10
)

_, test_acc = test_model.evaluate(test_ds)
print("Test accuracy: {:.2f}%".format(test_acc * 100))
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7712 - loss: 3.6884 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7386 - loss: 4.2129 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7715 - loss: 3.6833 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7618 - loss: 3.8387 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7641 - loss: 3.8029 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6990 - loss: 4.8519 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7606 - loss: 3.8588 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7594 - loss: 3.8783 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7724 - loss: 3.6683 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8030 - loss: 3.1748 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7497 - loss: 4.0346 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7505 - loss: 4.0219 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7197 - loss: 4.5176 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7370 - loss: 4.2383 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7369 - loss: 4.2406 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8017 - loss: 3.1955 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7889 - loss: 3.4033 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7723 - loss: 3.6694 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7628 - loss: 3.8235 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7722 - loss: 3.6719 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7851 - loss: 3.4635 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7712 - loss: 3.6886 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7588 - loss: 3.8882 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7608 - loss: 3.8547 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7570 - loss: 3.9170 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7556 - loss: 3.9399 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7346 - loss: 4.2781 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7672 - loss: 3.7531 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7608 - loss: 3.8547 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7359 - loss: 4.2575 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7442 - loss: 4.1237 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7080 - loss: 4.7062 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7799 - loss: 3.5475 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7601 - loss: 3.8670 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6985 - loss: 4.8588 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7612 - loss: 3.8497 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7309 - loss: 4.3370 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7160 - loss: 4.5775 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7730 - loss: 3.6592 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7645 - loss: 3.7956 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7222 - loss: 4.4771 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7958 - loss: 3.2905 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7585 - loss: 3.8928 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7656 - loss: 3.7786 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7696 - loss: 3.7142 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7467 - loss: 4.0821 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7599 - loss: 3.8695 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6910 - loss: 4.9812 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8038 - loss: 3.1627 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7065 - loss: 4.7302 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7318 - loss: 4.3226 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7283 - loss: 4.3793 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7662 - loss: 3.7692 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7814 - loss: 3.5230 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7412 - loss: 4.1716 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7178 - loss: 4.5481 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7824 - loss: 3.5076 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7617 - loss: 3.8414 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7641 - loss: 3.8016 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7314 - loss: 4.3295 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7720 - loss: 3.6756 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7287 - loss: 4.3731 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7547 - loss: 3.9546 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7643 - loss: 3.7985 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7504 - loss: 4.0235 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7844 - loss: 3.4749 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7357 - loss: 4.2598 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7655 - loss: 3.7794 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8047 - loss: 3.1486 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7638 - loss: 3.8076 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7766 - loss: 3.6006 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7714 - loss: 3.6842 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7511 - loss: 4.0116 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7657 - loss: 3.7767 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7752 - loss: 3.6229 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7223 - loss: 4.4753 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7377 - loss: 4.2278 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7558 - loss: 3.9362 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7684 - loss: 3.7323 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7637 - loss: 3.8094 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7584 - loss: 3.8948 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7730 - loss: 3.6596 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7491 - loss: 4.0436 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7990 - loss: 3.2396 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7676 - loss: 3.7461 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7467 - loss: 4.0824 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7543 - loss: 3.9598 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7626 - loss: 3.8263 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7346 - loss: 4.2772 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7855 - loss: 3.4577 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7403 - loss: 4.1861 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7680 - loss: 3.7387 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6832 - loss: 5.1064 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7520 - loss: 3.9965 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7576 - loss: 3.9072 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7658 - loss: 3.7747 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7865 - loss: 3.4410 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7872 - loss: 3.4302 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7473 - loss: 4.0731 - val_accuracy: 0.5000 - val_loss: 8.0590
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7561 - loss: 3.9309 - val_accuracy: 0.5000 - val_loss: 8.0590
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5649 - loss: 7.0137
# Test accuracy: 50.00%
